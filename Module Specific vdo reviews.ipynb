# %%
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Day 1

# %%
#channel_name='wion'

# %%
url='https://www.youtube.com/watch?v=LjPiaGAgZNE'
#print(url)

# %%
option = webdriver.ChromeOptions()
option.add_argument("--headless")
driver=webdriver.Chrome(options=option)
#driver.get('https://www.youtube.com/results?search_query={}'.format(str('Topgun Maverick Trailor')))
driver.get(url)
#driver.maximize_window()
prev_h=0
while True:
    height = driver.execute_script("""
                function getActualHeight() {
                    return Math.max(
                        Math.max(document.body.scrollHeight, document.documentElement.scrollHeight),
                        Math.max(document.body.offsetHeight, document.documentElement.offsetHeight),
                        Math.max(document.body.clientHeight, document.documentElement.clientHeight)
                    );
                }
                return getActualHeight();
            """)
    driver.execute_script(f"window.scrollTo({prev_h},{prev_h + 300})")
    # fix the time sleep value according to your network connection
    time.sleep(1)
    prev_h +=400  
    if prev_h >= 20000:
        break

# %%
com=[i.text for i in driver.find_elements_by_id('content-text')]
len(com)
# Out:
# 160

# %%
com
# Out:
# ['This anchor/journalist is excellent. I feel like it’s unbiased which is in sharp contrast to western media.',
#  'I become so much more informed after listening/watching such concise, broad and indepth reporting. Thank you.',
#  'Palki is like hot tea on a cold morning,  comforting.',
#  'The South Pacific countries should come together to form a Non-Aligned Union. This will make it easy for them to say NO to both China n US on military engagements while maintaining productive relationships with the two. They are not safe siding with one.',
#  'I always thought China and India’s relationship was fine and dandy. I never realized that China has been so aggressive towards India and all of ASEAN, not just the Pacific countries until watching this. Let’s return the favor to China and team up as an entire Asian collective in response to the China F*cking Threat! Thank you Palki! We, from the democratic countries in the Pacific, love you!',
# ...
