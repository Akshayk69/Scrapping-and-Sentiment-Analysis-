# %%
# This notebook cell runs the scraper script added to the repository.
# It calls the reusable run_scraper() function and saves results to results.csv.
from scraper import run_scraper

# Adjust the query or max results by editing the arguments below
run_scraper(query="topgun maverick trailer", max_results=10)

# %%
# Preview results if the job produced results.csv
import pandas as pd

try:
    df = pd.read_csv('results.csv')
    display(df.head())
except Exception as e:
    print('No results.csv found or failed to read it:', e)

# %% [markdown]
# Notes:
# - This notebook now delegates scraping to scraper.py (so it will behave the same as the scheduled GitHub Action).
# - Running the first cell will attempt to start a headless Chromium instance; ensure you have Chrome/Chromium and chromedriver available if you run this locally.
# - If you want to run the notebook on GitHub Actions, the scheduled workflow will produce results.csv as an artifact.
